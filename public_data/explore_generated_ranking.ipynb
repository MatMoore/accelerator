# %% [markdown]
# # Exploring the generated ranking from my initial dataset
#
# This notebook explores the click model I trained on the first dump of data from the Google Analytics. This covers about 100 queries which received at least 1000 clicks during that time period.
#
# The click model used is the Simplified Dynamic Bayesian Network. The goal of this notebook is to understand why the generated ranking seems worse than the original one.

# %% [markdown]
# First, import pandas and load the model parameters dataset:

# %%
import pandas as pd

# %%
df = pd.read_csv('data/pyclick-comparison/2018-04-26-model-uncertainty.csv')

# %%
df = df.set_index(['search_term_lowercase', 'result'])

# %% [markdown]
# My data uses content IDs, so use this data to translate into URLs and titles:

# %%
content = pd.read_csv('public_data/content_items.csv').set_index(['content_id'])
content.head()
# Out:
#                                                                               base_path  \
# content_id
# a6ac6905-080f-5cba-892b-c258529a07e4  /hmrc-internal-manuals/import-and-export-pipel...
# 91c1ad27-cb10-508c-a862-20cb22bc485b  /hmrc-internal-manuals/import-and-export-pipel...
# f4ac2cda-eff3-5c42-a2ac-2e71a33801a7  /hmrc-internal-manuals/vat-place-of-supply-tra...
# fd0ae676-feb6-5318-a2af-72b6fe489083  /hmrc-internal-manuals/vat-place-of-supply-tra...
# 4b0fcd96-88f3-5c6f-8f9e-e40e9b45207b  /hmrc-internal-manuals/excise-competent-offici...
#
#                                                                                   title
# content_id
# a6ac6905-080f-5cba-892b-c258529a07e4      Technical guidance: Control of imported goods
# 91c1ad27-cb10-508c-a862-20cb22bc485b                          Approval: Specimen Letter
# f4ac2cda-eff3-5c42-a2ac-2e71a33801a7                     Freight transport: definitions
# fd0ae676-feb6-5318-a2af-72b6fe489083  Freight transport: Place of Supply from 1 Janu...
# 4b0fcd96-88f3-5c6f-8f9e-e40e9b45207b  Introduction:  I want to exchange information ...

# %% [markdown]
# Now slice up the data by query, and rank based on estimated relevance + error.
#
# When I initially tested the dataset, I forgot to incorporate the error, but it doesn't seem to have made a huge difference.

# %%
def ranking(term):
    results = df.loc[term, :]
    results['relevance_low'] = results.relevance - results.relevance_error
    results = results.merge(content, how='left', left_index=True, right_index=True)
    results = results.set_index('base_path')
    results.sort_values('relevance_low', ascending=False, inplace=True)
    results['rank'] = results.relevance_low.rank(ascending=False, method='min')
    return results

# %%
self_assessment = ranking('self assessment')

# %% [markdown]
# # How are the current top results affected by this ranking?
#
# Overall the new ranking is significantly different from the current ranking. The mainstream guide is still ranked highly, but the other top results are different.

# %% [markdown]
# ## Ranked higher than before
#
# The HMRC guidance and collection of paper forms have gone from bottom of the ranking to the top.
#
#
# The top 5 results are
#
# 1. [/government/collections/self-assessment-hmrc-manuals](https://www.gov.uk/government/collections/self-assessment-hmrc-manuals) - Internal HMRC guidance (the most detailed guidance there is)
# 2. [/log-in-register-hmrc-online-services](https://www.gov.uk/log-in-register-hmrc-online-services) - Tax account service via governement gateway (not the preferred path to the service but does the same thing)
# 3. [/government/collections/self-assessment-helpsheets-main-self-assessment-tax-return](https://www.gov.uk/government/collections/self-assessment-helpsheets-main-self-assessment-tax-return) - Paper forms (just a list of them)
# 4. [/self-assessment-tax-returns](https://www.gov.uk/self-assessment-tax-returns) - Mainstream guide, points to preferred start page but no clear call to action
# 5. [/self-assessment-forms-and-helpsheets](https://www.gov.uk/self-assessment-forms-and-helpsheets) - Guide to the different forms and when you need them. Gives online and paper versions

# %%
self_assessment.head()
# Out:
#                                                     chosen  clicked  skipped  \
# base_path
# /government/collections/self-assessment-hmrc-ma...     7.0      7.0      2.0
# /log-in-register-hmrc-online-services               1703.0   1849.0    759.0
# /government/collections/self-assessment-helpshe...    19.0     19.0     11.0
# /self-assessment-tax-returns                        2010.0   2297.0   3208.0
# /self-assessment-forms-and-helpsheets                122.0    150.0    213.0
#
#                                                     clicked_error  \
# base_path
# /government/collections/self-assessment-hmrc-ma...       2.645751
# /log-in-register-hmrc-online-services                   43.000000
# /government/collections/self-assessment-helpshe...       4.358899
# /self-assessment-tax-returns                            47.927028
# /self-assessment-forms-and-helpsheets                   12.247449
#
#                                                     skipped_error  \
# base_path
# /government/collections/self-assessment-hmrc-ma...       1.414214
# /log-in-register-hmrc-online-services                   27.549955
# /government/collections/self-assessment-helpshe...       3.316625
# /self-assessment-tax-returns                            56.639209
# /self-assessment-forms-and-helpsheets                   14.594520
#
#                                                     chosen_error  \
# base_path
# /government/collections/self-assessment-hmrc-ma...      2.645751
# /log-in-register-hmrc-online-services                  41.267421
# /government/collections/self-assessment-helpshe...      4.358899
# /self-assessment-tax-returns                           44.833024
# /self-assessment-forms-and-helpsheets                  11.045361
#
#                                                     cov_clicked_skipped  \
# base_path
# /government/collections/self-assessment-hmrc-ma...             1.924631
# /log-in-register-hmrc-online-services                        609.358503
# /government/collections/self-assessment-helpshe...             7.436296
# /self-assessment-tax-returns                                1396.307947
# /self-assessment-forms-and-helpsheets                         91.943062
#
#                                                     examined  examined_error  \
# base_path
# /government/collections/self-assessment-hmrc-ma...       9.0        3.584587
# /log-in-register-hmrc-online-services                 2608.0       61.860464
# /government/collections/self-assessment-helpshe...      30.0        6.698701
# /self-assessment-tax-returns                          5505.0       91.091250
# /self-assessment-forms-and-helpsheets                  363.0       23.385597
#
#                                                     cov_clicked_examined ...   \
# base_path                                                                ...
# /government/collections/self-assessment-hmrc-ma...              8.686729 ...
# /log-in-register-hmrc-online-services                        2436.406732 ...
# /government/collections/self-assessment-helpshe...             26.744565 ...
# /self-assessment-tax-returns                                 3998.759852 ...
# /self-assessment-forms-and-helpsheets                         262.338629 ...
#
#                                                     attractiveness_error  \
# base_path
# /government/collections/self-assessment-hmrc-ma...              0.124738
# /log-in-register-hmrc-online-services                           0.006835
# /government/collections/self-assessment-helpshe...              0.058901
# /self-assessment-tax-returns                                    0.003654
# /self-assessment-forms-and-helpsheets                           0.014201
#
#                                                     cov_chosen_clicked  \
# base_path
# /government/collections/self-assessment-hmrc-ma...            6.989711
# /log-in-register-hmrc-online-services                      1771.890803
# /government/collections/self-assessment-helpshe...           18.972072
# /self-assessment-tax-returns                               2145.555242
# /self-assessment-forms-and-helpsheets                       135.078652
#
#                                                     satisfyingness  \
# base_path
# /government/collections/self-assessment-hmrc-ma...        1.000000
# /log-in-register-hmrc-online-services                     0.921038
# /government/collections/self-assessment-helpshe...        1.000000
# /self-assessment-tax-returns                              0.875054
# /self-assessment-forms-and-helpsheets                     0.813333
#
#                                                     satisfyingness_error  \
# base_path
# /government/collections/self-assessment-hmrc-ma...              0.020493
# /log-in-register-hmrc-online-services                           0.001488
# /government/collections/self-assessment-helpshe...              0.012439
# /self-assessment-tax-returns                                    0.001623
# /self-assessment-forms-and-helpsheets                           0.008161
#
#                                                     cov_attractiveness_satisfyingness  \
# base_path
# /government/collections/self-assessment-hmrc-ma...                           0.001462
# /log-in-register-hmrc-online-services                                        0.000006
# /government/collections/self-assessment-helpshe...                           0.000419
# /self-assessment-tax-returns                                                 0.000003
# /self-assessment-forms-and-helpsheets                                        0.000066
#
#                                                     relevance  \
# base_path
# /government/collections/self-assessment-hmrc-ma...   0.777778
# /log-in-register-hmrc-online-services                0.652991
# /government/collections/self-assessment-helpshe...   0.633333
# /self-assessment-tax-returns                         0.365123
# /self-assessment-forms-and-helpsheets                0.336088
#
#                                                     relevance_error  \
# base_path
# /government/collections/self-assessment-hmrc-ma...         0.116360
# /log-in-register-hmrc-online-services                      0.005758
# /government/collections/self-assessment-helpshe...         0.054779
# /self-assessment-tax-returns                               0.002865
# /self-assessment-forms-and-helpsheets                      0.010011
#
#                                                     relevance_low  \
# base_path
# /government/collections/self-assessment-hmrc-ma...       0.661418
# /log-in-register-hmrc-online-services                    0.647233
# /government/collections/self-assessment-helpshe...       0.578554
# /self-assessment-tax-returns                             0.362258
# /self-assessment-forms-and-helpsheets                    0.326077
#
#                                                                                                 title  \
# base_path
# /government/collections/self-assessment-hmrc-ma...                      Self Assessment: HMRC manuals
# /log-in-register-hmrc-online-services                              HMRC services: sign in or register
# /government/collections/self-assessment-helpshe...  Self Assessment forms and helpsheets: main Sel...
# /self-assessment-tax-returns                                              Self Assessment tax returns
# /self-assessment-forms-and-helpsheets                            Self Assessment forms and helpsheets
#
#                                                    rank
# base_path
# /government/collections/self-assessment-hmrc-ma...  1.0
# /log-in-register-hmrc-online-services               2.0
# /government/collections/self-assessment-helpshe...  3.0
# /self-assessment-tax-returns                        4.0
# /self-assessment-forms-and-helpsheets               5.0
#
# [5 rows x 21 columns]

# %% [markdown]
# The results that jumped up to the top are both based on < 20 views, because it's ranked so low down right now than not many people see them.
#
# This introduces a couple of problems.
#
# - Because we ignore clicks on the following page, we assume that these results were "chosen" even when the user could have kept browsing onto the next page. On hitting the bottom of the page, the user is also likely to revisit earlier links, or refine their query, which isn't accounted for in this model.
# - Since we have much less data for these results, we have to account for uncertainty in the number of clicks (if we sampled again we might get a very different result)
#
# However in this case:
#
# - The error contribution decreased our confidence in low-volume results, but didn't actually affect the new ranking
# - The satisfyingness was basically irrelevant - the ranking is also ordered by attractiveness

# %% [markdown]
# ## Ranked lower than before

# %% [markdown]
# The current top result, [/log-in-file-self-assessment-tax-return](https://www.gov.uk/log-in-file-self-assessment-tax-return) does not appear in the top 5:

# %%
self_assessment.loc['/log-in-file-self-assessment-tax-return']
# Out:
# chosen                                                                            2814
# clicked                                                                           3375
# skipped                                                                           5284
# clicked_error                                                                  58.0948
# skipped_error                                                                  72.6911
# chosen_error                                                                   53.0471
# cov_clicked_skipped                                                            2172.21
# examined                                                                          8659
# examined_error                                                                 114.033
# cov_clicked_examined                                                           6067.84
# attractiveness                                                                0.389768
# attractiveness_error                                                        0.00287646
# cov_chosen_clicked                                                             3077.23
# satisfyingness                                                                0.833778
# satisfyingness_error                                                        0.00159001
# cov_attractiveness_satisfyingness                                          2.61544e-06
# relevance                                                                      0.32498
# relevance_error                                                             0.00210621
# relevance_low                                                                 0.322874
# title                                Register for and file your Self Assessment tax...
# rank                                                                                 6
# Name: /log-in-file-self-assessment-tax-return, dtype: object

# %% [markdown]
# The reason is it has a very low clickthrough rate. Everyone examines it, but less than 40% of people click it

# %% [markdown]
# Even worse is current number 3: [/topic/personal-tax/self-assessment](https://www.gov.uk/topic/personal-tax/self-assessment)

# %%
self_assessment.loc['/topic/personal-tax/self-assessment']
# Out:
# chosen                                           522
# clicked                                          641
# skipped                                         2768
# clicked_error                                 25.318
# skipped_error                                52.6118
# chosen_error                                 22.8473
# cov_clicked_skipped                          685.166
# examined                                        3409
# examined_error                               69.1327
# cov_clicked_examined                         1603.17
# attractiveness                              0.188032
# attractiveness_error                      0.00422129
# cov_chosen_clicked                           577.598
# satisfyingness                              0.814353
# satisfyingness_error                      0.00393301
# cov_attractiveness_satisfyingness        9.49416e-06
# relevance                                   0.153124
# relevance_error                           0.00307515
# relevance_low                               0.150049
# title                                Self Assessment
# rank                                              11
# Name: /topic/personal-tax/self-assessment, dtype: object

# %% [markdown]
# Less than 20% of people who see this click on it, which makes sense because the snippet is really vague:
#
# #### Self Assessment
# > List of information about Self Assessment.

# %% [markdown]
# It's a similar story for "Personal tax account: sign in or set up"

# %%
self_assessment.loc['/personal-tax-account']
# Out:
# chosen                                                                   161
# clicked                                                                  169
# skipped                                                                  623
# clicked_error                                                             13
# skipped_error                                                          24.96
# chosen_error                                                         12.6886
# cov_clicked_skipped                                                  166.906
# examined                                                                 792
# examined_error                                                       33.5531
# cov_clicked_examined                                                 399.525
# attractiveness                                                      0.213384
# attractiveness_error                                              0.00890637
# cov_chosen_clicked                                                   164.709
# satisfyingness                                                      0.952663
# satisfyingness_error                                              0.00440561
# cov_attractiveness_satisfyingness                                2.24385e-05
# relevance                                                           0.203283
# relevance_error                                                    0.0079845
# relevance_low                                                       0.195298
# title                                Personal tax account: sign in or set up
# rank                                                                      10
# Name: /personal-tax-account, dtype: object

# %% [markdown]
# I assume that a lot of people don't know what a personal tax account is. If you just skim the titles it's not obvious that this is something you can use to file a self assessment.

# %% [markdown]
# # Another example: national minimum wage

# %%
min_wage = ranking('national minimum wage')
min_wage.loc[:, ['examined', 'attractiveness', 'attractiveness_error', 'satisfyingness', 'satisfyingness_error', 'relevance', 'relevance_error', 'relevance_low']]
# Out:
#                                                     examined  attractiveness  \
# base_path
# /national-minimum-wage-rates                           756.0        0.890212
# /hmrc-internal-manuals/compliance-operational-g...       1.0        1.000000
# /government/publications/pay-and-work-rights-co...       1.0        1.000000
# /government/collections/national-minimum-wage           39.0        0.538462
# /guidance/tell-hmrc-if-youve-underpaid-national...       2.0        0.500000
# /guidance/tell-hmrc-if-youve-underpaid-national...       2.0        0.500000
# /am-i-getting-minimum-wage                             115.0        0.373913
# /government/publications/national-minimum-wage-...       6.0        0.333333
# /national-minimum-wage                                  63.0        0.253968
# /government/publications/national-minimum-wage-...       4.0        0.250000
# /minimum-wage-calculator-employers                      83.0        0.180723
# /employment-rights-for-interns                          15.0        0.133333
# /national-minimum-wage-accommodation                    12.0        0.166667
# /government/collections/national-minimum-wage-l...      21.0        0.095238
# /tips-at-work                                            8.0        0.125000
# /government/publications/national-minimum-wage-...      12.0        0.083333
# /government/organisations/hm-revenue-customs            24.0        0.083333
# /hmrc-internal-manuals/compliance-operational-g...       1.0        1.000000
# /au-pairs-employment-law                                 3.0        0.000000
# /guidance/national-minimum-wage-work-experience...       1.0        0.000000
# /government/publications/national-minimum-wage-...       9.0        0.000000
# /government/publications/enforcing-national-min...       1.0        0.000000
# /government/publications/national-minimum-wage-...      12.0        0.000000
#
#                                                     attractiveness_error  \
# base_path
# /national-minimum-wage-rates                                    0.014939
# /hmrc-internal-manuals/compliance-operational-g...              0.410019
# /government/publications/pay-and-work-rights-co...              0.410019
# /government/collections/national-minimum-wage                   0.047181
# /guidance/tell-hmrc-if-youve-underpaid-national...              0.201956
# /guidance/tell-hmrc-if-youve-underpaid-national...              0.201956
# /am-i-getting-minimum-wage                                      0.024798
# /government/publications/national-minimum-wage-...              0.107020
# /national-minimum-wage                                          0.032180
# /government/publications/national-minimum-wage-...              0.127513
# /minimum-wage-calculator-employers                              0.026894
# /employment-rights-for-interns                                  0.059840
# /national-minimum-wage-accommodation                            0.069816
# /government/collections/national-minimum-wage-l...              0.046605
# /tips-at-work                                                   0.080790
# /government/publications/national-minimum-wage-...              0.059379
# /government/organisations/hm-revenue-customs                    0.041987
# /hmrc-internal-manuals/compliance-operational-g...              0.410019
# /au-pairs-employment-law                                        0.000000
# /guidance/national-minimum-wage-work-experience...              0.000000
# /government/publications/national-minimum-wage-...              0.000000
# /government/publications/enforcing-national-min...              0.000000
# /government/publications/national-minimum-wage-...              0.000000
#
#                                                     satisfyingness  \
# base_path
# /national-minimum-wage-rates                              0.922734
# /hmrc-internal-manuals/compliance-operational-g...        1.000000
# /government/publications/pay-and-work-rights-co...        1.000000
# /government/collections/national-minimum-wage             0.809524
# /guidance/tell-hmrc-if-youve-underpaid-national...        1.000000
# /guidance/tell-hmrc-if-youve-underpaid-national...        1.000000
# /am-i-getting-minimum-wage                                0.790698
# /government/publications/national-minimum-wage-...        1.000000
# /national-minimum-wage                                    0.812500
# /government/publications/national-minimum-wage-...        1.000000
# /minimum-wage-calculator-employers                        0.600000
# /employment-rights-for-interns                            1.000000
# /national-minimum-wage-accommodation                      0.500000
# /government/collections/national-minimum-wage-l...        1.000000
# /tips-at-work                                             1.000000
# /government/publications/national-minimum-wage-...        1.000000
# /government/organisations/hm-revenue-customs              0.500000
# /hmrc-internal-manuals/compliance-operational-g...        0.000000
# /au-pairs-employment-law                                  0.000000
# /guidance/national-minimum-wage-work-experience...        0.000000
# /government/publications/national-minimum-wage-...        0.000000
# /government/publications/enforcing-national-min...        0.000000
# /government/publications/national-minimum-wage-...        0.000000
#
#                                                     satisfyingness_error  \
# base_path
# /national-minimum-wage-rates                                    0.002450
# /hmrc-internal-manuals/compliance-operational-g...              0.054219
# /government/publications/pay-and-work-rights-co...              0.054219
# /government/collections/national-minimum-wage                   0.022124
# /guidance/tell-hmrc-if-youve-underpaid-national...              0.054219
# /guidance/tell-hmrc-if-youve-underpaid-national...              0.054219
# /am-i-getting-minimum-wage                                      0.016546
# /government/publications/national-minimum-wage-...              0.038339
# /national-minimum-wage                                          0.025067
# /government/publications/national-minimum-wage-...              0.054219
# /minimum-wage-calculator-employers                              0.046080
# /employment-rights-for-interns                                  0.038339
# /national-minimum-wage-accommodation                            0.148210
# /government/collections/national-minimum-wage-l...              0.038339
# /tips-at-work                                                   0.054219
# /government/publications/national-minimum-wage-...              0.054219
# /government/organisations/hm-revenue-customs                    0.148210
# /hmrc-internal-manuals/compliance-operational-g...              0.000000
# /au-pairs-employment-law                                        0.000000
# /guidance/national-minimum-wage-work-experience...              0.000000
# /government/publications/national-minimum-wage-...              0.000000
# /government/publications/enforcing-national-min...              0.000000
# /government/publications/national-minimum-wage-...              0.000000
#
#                                                     relevance  \
# base_path
# /national-minimum-wage-rates                         0.821429
# /hmrc-internal-manuals/compliance-operational-g...   1.000000
# /government/publications/pay-and-work-rights-co...   1.000000
# /government/collections/national-minimum-wage        0.435897
# /guidance/tell-hmrc-if-youve-underpaid-national...   0.500000
# /guidance/tell-hmrc-if-youve-underpaid-national...   0.500000
# /am-i-getting-minimum-wage                           0.295652
# /government/publications/national-minimum-wage-...   0.333333
# /national-minimum-wage                               0.206349
# /government/publications/national-minimum-wage-...   0.250000
# /minimum-wage-calculator-employers                   0.108434
# /employment-rights-for-interns                       0.133333
# /national-minimum-wage-accommodation                 0.083333
# /government/collections/national-minimum-wage-l...   0.095238
# /tips-at-work                                        0.125000
# /government/publications/national-minimum-wage-...   0.083333
# /government/organisations/hm-revenue-customs         0.041667
# /hmrc-internal-manuals/compliance-operational-g...   0.000000
# /au-pairs-employment-law                             0.000000
# /guidance/national-minimum-wage-work-experience...   0.000000
# /government/publications/national-minimum-wage-...   0.000000
# /government/publications/enforcing-national-min...   0.000000
# /government/publications/national-minimum-wage-...   0.000000
#
#                                                     relevance_error  \
# base_path
# /national-minimum-wage-rates                               0.012664
# /hmrc-internal-manuals/compliance-operational-g...         0.381614
# /government/publications/pay-and-work-rights-co...         0.381614
# /government/collections/national-minimum-wage              0.032868
# /guidance/tell-hmrc-if-youve-underpaid-national...         0.187775
# /guidance/tell-hmrc-if-youve-underpaid-national...         0.187775
# /am-i-getting-minimum-wage                                 0.016853
# /government/publications/national-minimum-wage-...         0.100261
# /national-minimum-wage                                     0.023104
# /government/publications/national-minimum-wage-...         0.120276
# /minimum-wage-calculator-employers                         0.013268
# /employment-rights-for-interns                             0.057071
# /national-minimum-wage-accommodation                       0.029026
# /government/collections/national-minimum-wage-l...         0.044617
# /tips-at-work                                              0.077115
# /government/publications/national-minimum-wage-...         0.056916
# /government/organisations/hm-revenue-customs               0.017226
# /hmrc-internal-manuals/compliance-operational-g...         0.000000
# /au-pairs-employment-law                                   0.000000
# /guidance/national-minimum-wage-work-experience...         0.000000
# /government/publications/national-minimum-wage-...         0.000000
# /government/publications/enforcing-national-min...         0.000000
# /government/publications/national-minimum-wage-...         0.000000
#
#                                                     relevance_low
# base_path
# /national-minimum-wage-rates                             0.808764
# /hmrc-internal-manuals/compliance-operational-g...       0.618386
# /government/publications/pay-and-work-rights-co...       0.618386
# /government/collections/national-minimum-wage            0.403029
# /guidance/tell-hmrc-if-youve-underpaid-national...       0.312225
# /guidance/tell-hmrc-if-youve-underpaid-national...       0.312225
# /am-i-getting-minimum-wage                               0.278800
# /government/publications/national-minimum-wage-...       0.233072
# /national-minimum-wage                                   0.183246
# /government/publications/national-minimum-wage-...       0.129724
# /minimum-wage-calculator-employers                       0.095166
# /employment-rights-for-interns                           0.076262
# /national-minimum-wage-accommodation                     0.054307
# /government/collections/national-minimum-wage-l...       0.050621
# /tips-at-work                                            0.047885
# /government/publications/national-minimum-wage-...       0.026417
# /government/organisations/hm-revenue-customs             0.024441
# /hmrc-internal-manuals/compliance-operational-g...       0.000000
# /au-pairs-employment-law                                 0.000000
# /guidance/national-minimum-wage-work-experience...       0.000000
# /government/publications/national-minimum-wage-...       0.000000
# /government/publications/enforcing-national-min...       0.000000
# /government/publications/national-minimum-wage-...       0.000000

# %% [markdown]
# For this query:
#
# - A bunch of results are stilling getting ranked high with only one click (the error seems underestimated)
# - The top result is unchanged
# - The clickthrough rate on the other results is quite low

# %% [markdown]
# # Why are the metrics unchanged if the results are different?
#
# The two metrics I have now both measure time saved from avoiding known bad results:
#
# - **Saved clicks** counts clicks that the user wouldn't need to make in the new ranking - if the current chosen result appears higher up than other things the user clicked on before, then with the new ranking they'd stop examining before seeing them.
#
# - **Change in rank** is the difference in rank of the current chosen result - if it now appears higher up in the ranking, the user doesn't have to examine as many results before finding it

# %% [markdown]
# ## Number of saved clicks
#
# **The limitation of this metric is it only tells half the story.** I measure known bad results that have been removed, but there could also be unknown bad results that have been added in above the chosen result.

# %% [markdown]
# ### Results

# %%
test_set = pd.read_csv('data/pyclick-comparison/2018-04-26-test_set-uncertainty.csv')
test_set = test_set.set_index(['search_term_lowercase', 'id'])
test_set.saved_clicks.sum()
# Out:
# 2308

# %%
test_set.loc['self assessment'].saved_clicks.value_counts()
# Out:
# 0    2402
# 1     136
# 2      18
# 3       1
# Name: saved_clicks, dtype: int64

# %%
test_set.loc['national minimum wage'].saved_clicks.value_counts()
# Out:
# 0    233
# 1      3
# Name: saved_clicks, dtype: int64

# %%
test_set.groupby('search_term_lowercase').sum().saved_clicks
# Out:
# search_term_lowercase
# [postcode]                  6
# apprenticeship              4
# apprenticeships             2
# ated                        7
# attendance allowance       15
# blue badge                  3
# budgeting loan             45
# car tax                    46
# carers allowance            5
# change address             31
# change of address          45
# child benefit               9
# child tax credit           12
# childcare                   8
# childcare account           2
# cis                         7
# companies house             4
# contact                     5
# contact hmrc                6
# contact number              2
# corporation tax            35
# council tax                19
# dart charge                 9
# dbs                        65
# divorce                    15
# driving licence            12
# driving test                1
# dvla                       10
# esa                         2
# exchange rates              6
#                          ...
# sa100                      46
# sa302                       0
# self assesment             32
# self assessment           175
# self employed              14
# sign in                     1
# sorn                        1
# ssp                         5
# state pension              89
# student finance            54
# tax                        35
# tax calculator             31
# tax code                    6
# tax codes                   9
# tax credit                 11
# tax credits                 7
# tax rebate                  7
# tax refund                 14
# tax return                 25
# theory test                 5
# universal                   7
# universal credit          203
# universal credit login      0
# universal credits           1
# utr                        19
# v62                         2
# vat                        44
# vehicle tax                 1
# visa                       25
# working tax credit         20
# Name: saved_clicks, Length: 108, dtype: int64

# %% [markdown]
# ## Change in rank
#
# This is the metric I am trying to optimise. For every user in the test set I have a "chosen" result that I want to place as high as possible. The sum across all sessions is the difference in the amount of URLs all the users have to examine to find their chosen results.
#
# **The limitation of this metric is that it ignores the fact that the user could choose a different result under the new ranking, that is better than or as good as the previously chosen result.**
#
# For example, using the training data we might estimate that a result seen by a very small number of people is really relevant. But the metric doesn't even care about this result because so few people chose it.
#
# **It's biased towards improvements in the results that are examined the most, i.e. rankings that are closer to the current ranking**

# %% [markdown]
# ### Results
# This metric has gotten worse with the new ranking.

# %%
test_set.change_in_rank.median()
# Out:
# -3.0

# %% [markdown]
# This is consistently worse for every query:

# %%
test_set.groupby('search_term_lowercase').median().change_in_rank
# Out:
# search_term_lowercase
# [postcode]               -63.0
# apprenticeship            -4.0
# apprenticeships           -1.0
# ated                      -4.0
# attendance allowance      -1.0
# blue badge                -2.0
# budgeting loan            -2.0
# car tax                   -4.0
# carers allowance          -1.0
# change address            -5.0
# change of address         -8.0
# child benefit             -2.0
# child tax credit           1.0
# childcare                 -6.0
# childcare account         -1.0
# cis                       -2.0
# companies house           -2.0
# contact                  -14.0
# contact hmrc              -2.0
# contact number            -3.0
# corporation tax           -3.5
# council tax               -7.0
# dart charge               -1.0
# dbs                       -2.0
# divorce                   -9.0
# driving licence           -4.0
# driving test              -2.0
# dvla                      -2.0
# esa                       -2.0
# exchange rates            -4.0
#                           ...
# sa100                     -2.0
# sa302                     -1.0
# self assesment            -2.0
# self assessment           -2.0
# self employed             -5.0
# sign in                   -4.0
# sorn                      -2.0
# ssp                       -3.0
# state pension             -5.0
# student finance           -1.0
# tax                       -7.0
# tax calculator            -1.0
# tax code                  -4.0
# tax codes                 -3.0
# tax credit                -1.0
# tax credits               -3.0
# tax rebate                -3.0
# tax refund                -2.0
# tax return                -3.0
# theory test               -2.0
# universal                 -1.0
# universal credit          -7.0
# universal credit login    -1.0
# universal credits         -1.0
# utr                        1.0
# v62                       -1.0
# vat                      -12.0
# vehicle tax               -1.0
# visa                      -4.0
# working tax credit         0.0
# Name: change_in_rank, Length: 108, dtype: float64

# %% [markdown]
# For self assessment queries only:

# %%
test_set.loc['self assessment'].change_in_rank.median()
# Out:
# -2.0

# %%
test_set.loc['self assessment'].change_in_rank.value_counts()
# Out:
# -5.0     1002
# -2.0      651
#  2.0      549
# -9.0      225
#  4.0       55
# -4.0       29
#  5.0        9
#  16.0       7
#  7.0        7
#  0.0        6
#  6.0        5
# -10.0       3
# -8.0        2
#  10.0       2
# -1.0        2
#  19.0       1
#  11.0       1
#  1.0        1
# Name: change_in_rank, dtype: int64

# %% [markdown]
# The change in rank just depends on the final thing chosen. This is the distribution of that:

# %%
worse_sessions = test_set[test_set.change_in_rank < 0]
final_clicks = worse_sessions.loc['self assessment'].final_click_url.value_counts()
final_clicks.to_frame().merge(content, how='left', left_index=True, right_index=True)
# Out:
#                                       final_click_url  \
# 02f7b151-bcd4-462b-b5dd-b02445b4417c                2
# 1b3d586c-538d-4983-b61a-c3a16c1efddb                1
# 32b54f44-fca1-4480-b13b-ddeb0b0238e1                2
# 40dab11d-12c3-4c55-a429-74138c6f7132                2
# 5ff12f59-7631-11e4-a3cb-005056011aef                2
# 5ff12f59-7631-11e4-a3cb-005056011aef                2
# 6a2bf66e-2313-4204-afd5-9940de5e1d66              946
# 7beb97b6-75c9-4aa7-86be-a733ab3a21aa              189
# 86f14e34-ba09-4e35-913e-af9e213cff2e               29
# 999dd0f5-41d3-4a63-8bb9-f00a68c129a8               36
# ce48b548-36d8-4f11-ad9b-b9149ae6c538                4
# f29ca4a8-8ed9-4b0f-bb6a-11e373095dee              649
# f4f2c99e-6d0a-4f2f-b3d0-ff2d00e33887               52
#
#                                                                               base_path  \
# 02f7b151-bcd4-462b-b5dd-b02445b4417c                         /pay-tax-debit-credit-card
# 1b3d586c-538d-4983-b61a-c3a16c1efddb                    /self-assessment-ready-reckoner
# 32b54f44-fca1-4480-b13b-ddeb0b0238e1                /estimate-self-assessment-penalties
# 40dab11d-12c3-4c55-a429-74138c6f7132                   /understand-self-assessment-bill
# 5ff12f59-7631-11e4-a3cb-005056011aef  /government/publications/self-assessment-regis...
# 5ff12f59-7631-11e4-a3cb-005056011aef  /government/publications/self-assessment-regis...
# 6a2bf66e-2313-4204-afd5-9940de5e1d66            /log-in-file-self-assessment-tax-return
# 7beb97b6-75c9-4aa7-86be-a733ab3a21aa                /topic/personal-tax/self-assessment
# 86f14e34-ba09-4e35-913e-af9e213cff2e                                      /contact-hmrc
# 999dd0f5-41d3-4a63-8bb9-f00a68c129a8                      /pay-self-assessment-tax-bill
# ce48b548-36d8-4f11-ad9b-b9149ae6c538                              /working-for-yourself
# f29ca4a8-8ed9-4b0f-bb6a-11e373095dee                       /self-assessment-tax-returns
# f4f2c99e-6d0a-4f2f-b3d0-ff2d00e33887                              /personal-tax-account
#
#                                                                                   title
# 02f7b151-bcd4-462b-b5dd-b02445b4417c          Pay your tax bill by debit or credit card
# 1b3d586c-538d-4983-b61a-c3a16c1efddb  Budget for your Self Assessment tax bill if yo...
# 32b54f44-fca1-4480-b13b-ddeb0b0238e1  Estimate your penalty for late Self Assessment...
# 40dab11d-12c3-4c55-a429-74138c6f7132           Understand your Self Assessment tax bill
# 5ff12f59-7631-11e4-a3cb-005056011aef                       Register for Self Assessment
# 5ff12f59-7631-11e4-a3cb-005056011aef                    Cofrestru ar gyfer Hunanasesiad
# 6a2bf66e-2313-4204-afd5-9940de5e1d66  Register for and file your Self Assessment tax...
# 7beb97b6-75c9-4aa7-86be-a733ab3a21aa                                    Self Assessment
# 86f14e34-ba09-4e35-913e-af9e213cff2e                                       Contact HMRC
# 999dd0f5-41d3-4a63-8bb9-f00a68c129a8                  Pay your Self Assessment tax bill
# ce48b548-36d8-4f11-ad9b-b9149ae6c538                               Working for yourself
# f29ca4a8-8ed9-4b0f-bb6a-11e373095dee                        Self Assessment tax returns
# f4f2c99e-6d0a-4f2f-b3d0-ff2d00e33887            Personal tax account: sign in or set up

# %% [markdown]
# # Different metrics
#
# ## Log likelihood of test data
#
# This is one of the evaluation methods used by PyClick
#
# - The model tells you the conditional click probabilities of each document clicked in each session
# - Want to maximise the likelihood of all of the clicks in the test set ([PyClick code](https://github.com/markovi/PyClick/blob/master/pyclick/click_models/Evaluation.py#L47))
# -  LL(Sessions | Model) = sum_{session in Sessions} log P(clicks in the session | Model)
# - Optimising for log likelihood is the same as optimising for likelihood, but it's simpler because you can sum all the log probabilities instead of multiplying all the probabilities

# %% [markdown]
# ## Perplexity
# This is an alternative metric used by PyClick.
#
# They reference a paper from [Dupret, Georges E. and Piwowarski, Benjamin](http://www.bpiwowar.net/wp-content/papercite-data/pdf/dupret2008a-user-browsing.pdf).
#
# It's also based on click probabilities given the model is true. I'm going to ignore it for now.
